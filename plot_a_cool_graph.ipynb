# %%
import matplotlib.pyplot as plt
import utils
from importlib import reload
import autopgd_base
from matplotlib.ticker import AutoMinorLocator
import matplotlib as mpl
plt.style.use(['../figures/style.mpl'])

# plot the accuracy for each model and each epsilon
labels = ['base', 'adv. 5e-2']
colors = ['blue', 'green']
linestyles = ['-', '--']

percent_data_used = ['10\%', '5\%', '2.5\%']
aurocs = [0.732, 0.695, 0.618]

base_auroc = 0.685

# draw line for base model
plt.plot([0, 2], [base_auroc, base_auroc], label='base, fine-tuned on 10\%', linestyle='--', color='blue')

# draw line for adv model
plt.plot(percent_data_used, aurocs, label='adv. 1e-2', marker='o', linestyle='-', color='green')





# for model_path, color, linestyle, label in zip(metrics, colors, linestyles, labels):
#     # get the metrics for this model
#     model_metrics = metrics[model_path]
    
#     # get the accuracy for each epsilon
#     acc = [model_metrics[eps]['ap'] for eps in model_metrics]
    
#     # plot the accuracy
#     plt.plot([str(eps) for eps in eps_list], acc, label=label, marker='o', linestyle=linestyle, linewidth=1, color=color)
    
plt.grid()

# change figure size
fig = plt.gcf()
fig.set_size_inches(6, 3)

# make it higher resolution
mpl.rcParams['figure.dpi'] = 300

# Set font size
plt.xticks(fontsize=12)
# y ticks every 0.05
plt.yticks(ticks=[0.6, 0.65, 0.7, 0.75], fontsize=12)


# set remaining fonts such as axis and legend
plt.legend(fontsize=12)
plt.xlabel('Percentage of data used', fontsize=12)
plt.ylabel('AUPRC on CODE-15\%', fontsize=12)

plt.ylim(0.6, 0.75)

plt.savefig('../figures/code_auprc_data_size.pdf', bbox_inches='tight')

plt.show()

# %%
# see style.available for a list of styles for font.serif 
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
import matplotlib.font_manager
matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['/usr/share/fonts/truetype/noto/NotoSansTelugu-Bold.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSansSinhala-ExtraCondensedBlack.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSerifSinhala-Regular.ttf',
#  '/usr/share/fonts/truetype/noto/NotoLoopedLao-CondensedExtraBold.ttf',
#  '/usr/share/fonts/opentype/urw-base35/C059-BdIta.otf',
#  '/usr/share/fonts/truetype/noto/NotoSansArmenian-ExtraLight.ttf',
#  '/usr/share/fonts/truetype/ubuntu/Ubuntu-BI.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSansMyanmar-Black.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSerifGurmukhi-ExtraBold.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSerifTamil-ExtraBold.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSansMyanmar-SemiCondensedBold.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSansKayahLi-Regular.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSansMono-SemiCondensedExtraLight.ttf',
#  '/usr/share/fonts/truetype/noto/NotoSansSinhala-ExtraCondensedSemiBold.ttf',
# ...
